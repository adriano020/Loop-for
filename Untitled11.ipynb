# %% [markdown]
# <a href="https://colab.research.google.com/github/adriano020/Loop-for/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(10):
  print('teste', i)
# Out:
# teste 0
# teste 1
# teste 2
# teste 3
# teste 4
# teste 5
# teste 6
# teste 7
# teste 8
# teste 9

# %%
frutas = ['maca','banana','laranja']
for item in frutas:
  print(item)
# Out:
# maca
# banana
# laranja

# %%
bd = ['felipe','jose','maria','luiz']
for item in bd:
  print(item)
# Out:
# felipe
# jose
# maria
# luiz

# %%
listas_vendas = [1000,5000,800,1500,2000,2300]
for i in listas_vendas:
  print(i)
# Out:
# 1000
# 5000
# 800
# 1500
# 2000
# 2300

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_bonus = 0.1
for venda in lista_vendas:
  if venda >= 1200:
    bonus = percentual_bonus *venda
  else:
    bonus = 0
  print(bonus)
# Out:
# 0
# 0
# 0
# 150.0
# 200.0
# 230.0

# %%
vendas_diarias = [20,30,40,50]
meta = 30
dias_acima_da_meta = 0
for diaria in vendas_diarias:
  if diaria > meta:
    dias_acima_da_meta = dias_acima_da_meta + 1
print(dias_acima_da_meta)
# Out:
# 2

# %%
vendas_diarias = [2000,3000,2500,4000,1800,5000,2700]
meta = 2500
dias_acima_da_meta = 0
for diaria in vendas_diarias:
  if diaria > meta:
    dias_acima_da_meta = dias_acima_da_meta +1
print(dias_acima_da_meta)
# Out:
# 4

# %%
vendas_diarias = [1000,500,800,1500,2000,2300]
meta = 1200
dias_acima_da_meta = 0
for diaria in vendas_diarias:
  if diaria >= meta:
    dias_acima_da_meta = dias_acima_da_meta + 1
print(dias_acima_da_meta)
# Out:
# 3

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_bonus = 0.1
bonus_extra = 50
for vendas in lista_vendas:
  if vendas >= meta
    bonus = percentual_bonus * vendas
  else:
    bonus = 0
  print(bonus)
# Out:
#   File "/tmp/ipykernel_8860/1233031671.py", line 6
#     if vendas >= meta
#                      ^
# SyntaxError: expected ':'
